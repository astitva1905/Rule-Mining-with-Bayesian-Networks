# %% [markdown]
# # Bayesian Association Rule Mining Algorithm

# %% [markdown]
# <h4> 1 - Importing the required libraries

# %%
# !pip install pgmpy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting pgmpy
#   Downloading pgmpy-0.1.21-py3-none-any.whl (1.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 20.2 MB/s eta 0:00:00
# Requirement already satisfied: scipy in /usr/local/lib/python3.8/dist-packages (from pgmpy) (1.7.3)
# Requirement already satisfied: pandas in /usr/local/lib/python3.8/dist-packages (from pgmpy) (1.3.5)
# Requirement already satisfied: torch in /usr/local/lib/python3.8/dist-packages (from pgmpy) (1.13.1+cu116)
# Requirement already satisfied: networkx in /usr/local/lib/python3.8/dist-packages (from pgmpy) (3.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.8/dist-packages (from pgmpy) (4.64.1)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.8/dist-packages (from pgmpy) (1.0.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.8/dist-packages (from pgmpy) (1.21.6)
# Requirement already satisfied: pyparsing in /usr/local/lib/python3.8/dist-packages (from pgmpy) (3.0.9)
# Requirement already satisfied: statsmodels in /usr/local/lib/python3.8/dist-packages (from pgmpy) (0.12.2)
# Requirement already satisfied: opt-einsum in /usr/local/lib/python3.8/dist-packages (from pgmpy) (3.3.0)
# Requirement already satisfied: joblib in /usr/local/lib/python3.8/dist-packages (from pgmpy) (1.2.0)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.8/dist-packages (from pandas->pgmpy) (2022.7)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.8/dist-packages (from pandas->pgmpy) (2.8.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from scikit-learn->pgmpy) (3.1.0)
# Requirement already satisfied: patsy>=0.5 in /usr/local/lib/python3.8/dist-packages (from statsmodels->pgmpy) (0.5.3)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.8/dist-packages (from torch->pgmpy) (4.4.0)
# Requirement already satisfied: six in /usr/local/lib/python3.8/dist-packages (from patsy>=0.5->statsmodels->pgmpy) (1.15.0)
# Installing collected packages: pgmpy
# Successfully installed pgmpy-0.1.21

# %%
import numpy as np
import pandas as pd
import os 
from tqdm import tqdm
from mlxtend.frequent_patterns import apriori, association_rules
from pgmpy.models import BayesianNetwork
import io

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# <h4>2- Loading and exploring the data

# %%
data = pd.read_csv("/content/drive/MyDrive/FDS_proj/Online_Retail_csv.csv",encoding= 'unicode_escape')
data
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#              InvoiceDate  UnitPrice  CustomerID         Country
# 0        01-12-2010 8.26       2.55     17850.0  United Kingdom
# 1        01-12-2010 8.26       3.39     17850.0  United Kingdom
# 2        01-12-2010 8.26       2.75     17850.0  United Kingdom
# 3        01-12-2010 8.26       3.39     17850.0  United Kingdom
# 4        01-12-2010 8.26       3.39     17850.0  United Kingdom
# ...                  ...        ...         ...             ...
# 541904  09-12-2011 12.50       0.85     12680.0          France
# 541905  09-12-2011 12.50       2.10     12680.0          France
# 541906  09-12-2011 12.50       4.15     12680.0          France
# 541907  09-12-2011 12.50       4.15     12680.0          France
# 541908  09-12-2011 12.50       4.95     12680.0          France
#
# [541909 rows x 8 columns]

# %% [markdown]
# We've successfully transfered the "Online Retail" dataset to a pandas DataFrame. Let's now analyse the dataset further:

# %%
data.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#        InvoiceDate  UnitPrice  CustomerID         Country
# 0  01-12-2010 8.26       2.55     17850.0  United Kingdom
# 1  01-12-2010 8.26       3.39     17850.0  United Kingdom
# 2  01-12-2010 8.26       2.75     17850.0  United Kingdom
# 3  01-12-2010 8.26       3.39     17850.0  United Kingdom
# 4  01-12-2010 8.26       3.39     17850.0  United Kingdom

# %%
data.columns
# Out:
# Index(['InvoiceNo', 'StockCode', 'Description', 'Quantity', 'InvoiceDate',
#        'UnitPrice', 'CustomerID', 'Country'],
#       dtype='object')

# %% [markdown]
# Our dataset has entries about numerous countries:

# %%
data.Country.unique()
# Out:
# array(['United Kingdom', 'France', 'Australia', 'Netherlands', 'Germany',
#        'Norway', 'EIRE', 'Switzerland', 'Spain', 'Poland', 'Portugal',
#        'Italy', 'Belgium', 'Lithuania', 'Japan', 'Iceland',
#        'Channel Islands', 'Denmark', 'Cyprus', 'Sweden', 'Austria',
#        'Israel', 'Finland', 'Bahrain', 'Greece', 'Hong Kong', 'Singapore',
#        'Lebanon', 'United Arab Emirates', 'Saudi Arabia',
#        'Czech Republic', 'Canada', 'Unspecified', 'Brazil', 'USA',
#        'European Community', 'Malta', 'RSA'], dtype=object)

# %% [markdown]
#  <h4>3- Cleaning the Data

# %% [markdown]
# We clean the dataset by removing unnecessary characters and incomplete rows:

# %%
data['Description'] = data['Description'].str.strip()
  
# Removing rows with no invoice number
data.dropna(axis = 0, subset =['InvoiceNo'], inplace = True)
data['InvoiceNo'] = data['InvoiceNo'].astype('str')
  
# Removing credit transactions
data = data[~data['InvoiceNo'].str.contains('C')]

# %% [markdown]
# <h4>4- Choosing a specific region for our demonstration

# %% [markdown]
# We've selected France to demonstrate our Bayesian Network. We create a table containing data about transactions of France:

# %%
basket_France = (data[data['Country'] =="France"]
          .groupby(['InvoiceNo', 'Description'])['Quantity']
          .sum().unstack().reset_index().fillna(0)
          .set_index('InvoiceNo'))
basket_France
# Out:
# Description  10 COLOUR SPACEBOY PEN  12 COLOURED PARTY BALLOONS  \
# InvoiceNo
# 536370                          0.0                         0.0
# 536852                          0.0                         0.0
# 536974                          0.0                         0.0
# 537065                          0.0                         0.0
# 537463                          0.0                         0.0
# ...                             ...                         ...
# 580986                          0.0                         0.0
# 581001                          0.0                         0.0
# 581171                          0.0                         0.0
# 581279                          0.0                         0.0
# 581587                          0.0                         0.0
#
# Description  12 EGG HOUSE PAINTED WOOD  12 MESSAGE CARDS WITH ENVELOPES  \
# InvoiceNo
# 536370                             0.0                              0.0
# 536852                             0.0                              0.0
# 536974                             0.0                              0.0
# 537065                             0.0                              0.0
# 537463                             0.0                              0.0
# ...                                ...                              ...
# 580986                             0.0                              0.0
# 581001                             0.0                              0.0
# 581171                             0.0                              0.0
# 581279                             0.0                              0.0
# 581587                             0.0                              0.0
#
# Description  12 PENCIL SMALL TUBE WOODLAND  \
# InvoiceNo
# 536370                                 0.0
# 536852                                 0.0
# 536974                                 0.0
# 537065                                 0.0
# 537463                                 0.0
# ...                                    ...
# 580986                                 0.0
# 581001                                 0.0
# 581171                                 0.0
# 581279                                 0.0
# 581587                                 0.0
#
# Description  12 PENCILS SMALL TUBE RED RETROSPOT  12 PENCILS SMALL TUBE SKULL  \
# InvoiceNo
# 536370                                       0.0                          0.0
# 536852                                       0.0                          0.0
# 536974                                       0.0                          0.0
# 537065                                       0.0                          0.0
# 537463                                       0.0                          0.0
# ...                                          ...                          ...
# 580986                                       0.0                          0.0
# 581001                                       0.0                          0.0
# 581171                                       0.0                          0.0
# 581279                                       0.0                          0.0
# 581587                                       0.0                          0.0
#
# Description  12 PENCILS TALL TUBE POSY  12 PENCILS TALL TUBE RED RETROSPOT  \
# InvoiceNo
# 536370                             0.0                                 0.0
# 536852                             0.0                                 0.0
# 536974                             0.0                                 0.0
# 537065                             0.0                                 0.0
# 537463                             0.0                                 0.0
# ...                                ...                                 ...
# 580986                             0.0                                 0.0
# 581001                             0.0                                 0.0
# 581171                             0.0                                 0.0
# 581279                             0.0                                 0.0
# 581587                             0.0                                 0.0
#
# Description  12 PENCILS TALL TUBE WOODLAND  ...  WRAP VINTAGE PETALS  DESIGN  \
# InvoiceNo                                   ...
# 536370                                 0.0  ...                          0.0
# 536852                                 0.0  ...                          0.0
# 536974                                 0.0  ...                          0.0
# 537065                                 0.0  ...                          0.0
# 537463                                 0.0  ...                          0.0
# ...                                    ...  ...                          ...
# 580986                                 0.0  ...                          0.0
# 581001                                 0.0  ...                          0.0
# 581171                                 0.0  ...                          0.0
# 581279                                 0.0  ...                          0.0
# 581587                                 0.0  ...                          0.0
#
# Description  YELLOW COAT RACK PARIS FASHION  YELLOW GIANT GARDEN THERMOMETER  \
# InvoiceNo
# 536370                                  0.0                              0.0
# 536852                                  0.0                              0.0
# 536974                                  0.0                              0.0
# 537065                                  0.0                              0.0
# 537463                                  0.0                              0.0
# ...                                     ...                              ...
# 580986                                  0.0                              0.0
# 581001                                  0.0                              0.0
# 581171                                  0.0                              0.0
# 581279                                  0.0                              0.0
# 581587                                  0.0                              0.0
#
# Description  YELLOW SHARK HELICOPTER  ZINC  STAR T-LIGHT HOLDER  \
# InvoiceNo
# 536370                           0.0                        0.0
# 536852                           0.0                        0.0
# 536974                           0.0                        0.0
# 537065                           0.0                        0.0
# 537463                           0.0                        0.0
# ...                              ...                        ...
# 580986                           0.0                        0.0
# 581001                           0.0                        0.0
# 581171                           0.0                        0.0
# 581279                           0.0                        0.0
# 581587                           0.0                        0.0
#
# Description  ZINC FOLKART SLEIGH BELLS  ZINC HERB GARDEN CONTAINER  \
# InvoiceNo
# 536370                             0.0                         0.0
# 536852                             0.0                         0.0
# 536974                             0.0                         0.0
# 537065                             0.0                         0.0
# 537463                             0.0                         0.0
# ...                                ...                         ...
# 580986                             0.0                         0.0
# 581001                             0.0                         0.0
# 581171                             0.0                         0.0
# 581279                             0.0                         0.0
# 581587                             0.0                         0.0
#
# Description  ZINC METAL HEART DECORATION  ZINC T-LIGHT HOLDER STAR LARGE  \
# InvoiceNo
# 536370                               0.0                             0.0
# 536852                               0.0                             0.0
# 536974                               0.0                             0.0
# 537065                               0.0                             0.0
# 537463                               0.0                             0.0
# ...                                  ...                             ...
# 580986                               0.0                             0.0
# 581001                               0.0                             0.0
# 581171                               0.0                             0.0
# 581279                               0.0                             0.0
# 581587                               0.0                             0.0
#
# Description  ZINC T-LIGHT HOLDER STARS SMALL
# InvoiceNo
# 536370                                   0.0
# 536852                                   0.0
# 536974                                   0.0
# 537065                                   0.0
# 537463                                   0.0
# ...                                      ...
# 580986                                   0.0
# 581001                                   0.0
# 581171                                   0.0
# 581279                                   0.0
# 581587                                   0.0
#
# [392 rows x 1563 columns]

# %% [markdown]
# <h4>5- Converting integer values to boolean

# %% [markdown]
# For association rules, it is important to know if an event has occurred. However, in the same transaction it doesn't matter if the same item was bought at a quantity of 1000 or at a quantity of 1. All that matters is it was bought.
#
# Thus, we convert any non zero integers to a true boolean value (the integer 1).

# %%
# Defining the hot encoding function to make the data suitable 
# for the concerned libraries
def int_to_bool(x):
    if(x<= 0):
        return 0
    if(x>= 1):
        return 1
  
# Encoding the datasets
basket_encoded = basket_France.applymap(int_to_bool)
basket_France = basket_encoded

# %% [markdown]
# <h4> 6- Building apriori association rules

# %% [markdown]
# We now use an apriori algorithm to create the association rules based on our dataset:

# %%
# Building the model
frq_items = apriori(basket_France, min_support = 0.05, use_colnames = True)
  
# Collecting the inferred rules in a dataframe
rules = association_rules(frq_items, metric ="lift", min_threshold = 1)
rules = rules.sort_values(['confidence', 'lift'], ascending =[False, False])

# %%
rules.head()
# Out:
#                                            antecedents  \
# 45                        (JUMBO BAG WOODLAND ANIMALS)
# 260  (RED TOADSTOOL LED NIGHT LIGHT, PLASTERS IN TI...
# 272  (RED TOADSTOOL LED NIGHT LIGHT, PLASTERS IN TI...
# 302  (SET/6 RED SPOTTY PAPER CUPS, SET/20 RED RETRO...
# 301  (SET/6 RED SPOTTY PAPER PLATES, SET/20 RED RET...
#
#                          consequents  antecedent support  consequent support  \
# 45                         (POSTAGE)            0.076531            0.765306
# 260                        (POSTAGE)            0.051020            0.765306
# 272                        (POSTAGE)            0.053571            0.765306
# 302  (SET/6 RED SPOTTY PAPER PLATES)            0.102041            0.127551
# 301    (SET/6 RED SPOTTY PAPER CUPS)            0.102041            0.137755
#
#       support  confidence      lift  leverage  conviction
# 45   0.076531       1.000  1.306667  0.017961         inf
# 260  0.051020       1.000  1.306667  0.011974         inf
# 272  0.053571       1.000  1.306667  0.012573         inf
# 302  0.099490       0.975  7.644000  0.086474   34.897959
# 301  0.099490       0.975  7.077778  0.085433   34.489796

# %% [markdown]
# We see that we have acquired many association rules. Consider #302 as an example: This rule says that buying paper plates (red) -> buying paper cups. Logically this makes sense as we expect someone buying paper plates (say, for a party) to also buy paper cups along with it.

# %% [markdown]
# Varius values like confidence, support, lift for the apriori rules are also given in the table. We show a table below, that only focuses on the rule itself:

# %%
rules[['antecedents', 'consequents',]]
# Out:
#                                            antecedents  \
# 45                        (JUMBO BAG WOODLAND ANIMALS)
# 260  (RED TOADSTOOL LED NIGHT LIGHT, PLASTERS IN TI...
# 272  (RED TOADSTOOL LED NIGHT LIGHT, PLASTERS IN TI...
# 302  (SET/6 RED SPOTTY PAPER CUPS, SET/20 RED RETRO...
# 301  (SET/6 RED SPOTTY PAPER PLATES, SET/20 RED RET...
# ..                                                 ...
# 36                                           (POSTAGE)
# 27                                           (POSTAGE)
# 97                                           (POSTAGE)
# 226                                          (POSTAGE)
# 213                                          (POSTAGE)
#
#                                            consequents
# 45                                           (POSTAGE)
# 260                                          (POSTAGE)
# 272                                          (POSTAGE)
# 302                    (SET/6 RED SPOTTY PAPER PLATES)
# 301                      (SET/6 RED SPOTTY PAPER CUPS)
# ..                                                 ...
# 36                            (JAM MAKING SET PRINTED)
# 27                   (CIRCUS PARADE CHILDRENS EGG CUP)
# 97                                     (PARTY BUNTING)
# 226      (LUNCH BAG RED RETROSPOT, LUNCH BAG WOODLAND)
# 213  (LUNCH BAG APPLE DESIGN, LUNCH BAG SPACEBOY DE...
#
# [348 rows x 2 columns]

# %% [markdown]
# **Creating a Bayesian Network for every Apriori rule**

# %%
#extracting important columns as lists 
ant = rules['antecedents'].tolist()
con = rules['consequents'].tolist()
ant_supports = rules['antecedent support'].to_list()
con_supports = rules['consequent support'].to_list()

#storing the association rules as tuples in an array:
atob = []
for i in range(len(ant)):
  a = list(ant[i])
  b = list(con[i])
  el = [a,b]
  atob.append(el)

# %%
#The list that stores all the bayesian networks
networks = []


for rule in atob:
  a = rule[0]
  b = rule[1]

  edges = []
  for itema in a:
    for itemb in b:
      edges.append((itema,itemb))
      #adding an edge from itema to itemb

  #creating the network for the given rule
  #and appending it to the 'networks' array
  networks.append(BayesianNetwork(edges))



#Training the CPDS for each node
i = 0
for n in networks:
  n.fit(basket_France)
  print("Network " + str(i) + " is being initialised")
  i+=1
# Out:
# Network 0 is being initialised
# Network 1 is being initialised
# Network 2 is being initialised
# Network 3 is being initialised
# Network 4 is being initialised
# Network 5 is being initialised
# Network 6 is being initialised
# Network 7 is being initialised
# Network 8 is being initialised
# Network 9 is being initialised
# Network 10 is being initialised
# Network 11 is being initialised
# Network 12 is being initialised
# Network 13 is being initialised
# Network 14 is being initialised
# Network 15 is being initialised
# Network 16 is being initialised
# Network 17 is being initialised
# Network 18 is being initialised
# Network 19 is being initialised
# Network 20 is being initialised
# Network 21 is being initialised
# Network 22 is being initialised
# Network 23 is being initialised
# Network 24 is being initialised
# Network 25 is being initialised
# Network 26 is being initialised
# Network 27 is being initialised
# Network 28 is being initialised
# Network 29 is being initialised
# Network 30 is being initialised
# Network 31 is being initialised
# Network 32 is being initialised
# Network 33 is being initialised
# Network 34 is being initialised
# Network 35 is being initialised
# Network 36 is being initialised
# Network 37 is being initialised
# Network 38 is being initialised
# Network 39 is being initialised
# Network 40 is being initialised
# Network 41 is being initialised
# Network 42 is being initialised
# Network 43 is being initialised
# Network 44 is being initialised
# Network 45 is being initialised
# Network 46 is being initialised
# Network 47 is being initialised
# Network 48 is being initialised
# Network 49 is being initialised
# Network 50 is being initialised
# Network 51 is being initialised
# Network 52 is being initialised
# Network 53 is being initialised
# Network 54 is being initialised
# Network 55 is being initialised
# Network 56 is being initialised
# Network 57 is being initialised
# Network 58 is being initialised
# Network 59 is being initialised
# Network 60 is being initialised
# Network 61 is being initialised
# Network 62 is being initialised
# Network 63 is being initialised
# Network 64 is being initialised
# Network 65 is being initialised
# Network 66 is being initialised
# Network 67 is being initialised
# Network 68 is being initialised
# Network 69 is being initialised
# Network 70 is being initialised
# Network 71 is being initialised
# Network 72 is being initialised
# Network 73 is being initialised
# Network 74 is being initialised
# Network 75 is being initialised
# Network 76 is being initialised
# Network 77 is being initialised
# Network 78 is being initialised
# Network 79 is being initialised
# Network 80 is being initialised
# Network 81 is being initialised
# Network 82 is being initialised
# Network 83 is being initialised
# Network 84 is being initialised
# Network 85 is being initialised
# Network 86 is being initialised
# Network 87 is being initialised
# Network 88 is being initialised
# Network 89 is being initialised
# /usr/local/lib/python3.8/dist-packages/pgmpy/factors/discrete/CPD.py:332: RuntimeWarning: invalid value encountered in true_divide
#   tabular_cpd.values = (cpd / cpd.sum(axis=0)).reshape(tabular_cpd.cardinality)
# Network 90 is being initialised
# Network 91 is being initialised
# Network 92 is being initialised
# Network 93 is being initialised
# Network 94 is being initialised
# Network 95 is being initialised
# Network 96 is being initialised
# Network 97 is being initialised
# Network 98 is being initialised
# Network 99 is being initialised
# Network 100 is being initialised
# Network 101 is being initialised
# Network 102 is being initialised
# Network 103 is being initialised
# Network 104 is being initialised
# Network 105 is being initialised
# Network 106 is being initialised
# Network 107 is being initialised
# Network 108 is being initialised
# Network 109 is being initialised
# Network 110 is being initialised
# Network 111 is being initialised
# Network 112 is being initialised
# Network 113 is being initialised
# Network 114 is being initialised
# Network 115 is being initialised
# Network 116 is being initialised
# Network 117 is being initialised
# Network 118 is being initialised
# Network 119 is being initialised
# Network 120 is being initialised
# Network 121 is being initialised
# Network 122 is being initialised
# Network 123 is being initialised
# Network 124 is being initialised
# Network 125 is being initialised
# Network 126 is being initialised
# Network 127 is being initialised
# Network 128 is being initialised
# Network 129 is being initialised
# Network 130 is being initialised
# Network 131 is being initialised
# Network 132 is being initialised
# Network 133 is being initialised
# Network 134 is being initialised
# Network 135 is being initialised
# Network 136 is being initialised
# Network 137 is being initialised
# Network 138 is being initialised
# Network 139 is being initialised
# Network 140 is being initialised
# Network 141 is being initialised
# Network 142 is being initialised
# Network 143 is being initialised
# Network 144 is being initialised
# Network 145 is being initialised
# Network 146 is being initialised
# Network 147 is being initialised
# Network 148 is being initialised
# Network 149 is being initialised
# Network 150 is being initialised
# Network 151 is being initialised
# Network 152 is being initialised
# Network 153 is being initialised
# Network 154 is being initialised
# Network 155 is being initialised
# Network 156 is being initialised
# Network 157 is being initialised
# Network 158 is being initialised
# Network 159 is being initialised
# Network 160 is being initialised
# Network 161 is being initialised
# Network 162 is being initialised
# Network 163 is being initialised
# Network 164 is being initialised
# Network 165 is being initialised
# Network 166 is being initialised
# Network 167 is being initialised
# Network 168 is being initialised
# Network 169 is being initialised
# Network 170 is being initialised
# Network 171 is being initialised
# Network 172 is being initialised
# Network 173 is being initialised
# Network 174 is being initialised
# Network 175 is being initialised
# Network 176 is being initialised
# Network 177 is being initialised
# Network 178 is being initialised
# Network 179 is being initialised
# Network 180 is being initialised
# Network 181 is being initialised
# Network 182 is being initialised
# Network 183 is being initialised
# Network 184 is being initialised
# Network 185 is being initialised
# Network 186 is being initialised
# Network 187 is being initialised
# Network 188 is being initialised
# Network 189 is being initialised
# Network 190 is being initialised
# Network 191 is being initialised
# Network 192 is being initialised
# Network 193 is being initialised
# Network 194 is being initialised
# Network 195 is being initialised
# Network 196 is being initialised
# Network 197 is being initialised
# Network 198 is being initialised
# Network 199 is being initialised
# Network 200 is being initialised
# Network 201 is being initialised
# Network 202 is being initialised
# Network 203 is being initialised
# Network 204 is being initialised
# Network 205 is being initialised
# Network 206 is being initialised
# Network 207 is being initialised
# Network 208 is being initialised
# Network 209 is being initialised
# Network 210 is being initialised
# Network 211 is being initialised
# Network 212 is being initialised
# Network 213 is being initialised
# Network 214 is being initialised
# Network 215 is being initialised
# Network 216 is being initialised
# Network 217 is being initialised
# Network 218 is being initialised
# Network 219 is being initialised
# Network 220 is being initialised
# Network 221 is being initialised
# Network 222 is being initialised
# Network 223 is being initialised
# Network 224 is being initialised
# Network 225 is being initialised
# Network 226 is being initialised
# Network 227 is being initialised
# Network 228 is being initialised
# Network 229 is being initialised
# Network 230 is being initialised
# Network 231 is being initialised
# Network 232 is being initialised
# Network 233 is being initialised
# Network 234 is being initialised
# Network 235 is being initialised
# Network 236 is being initialised
# Network 237 is being initialised
# Network 238 is being initialised
# Network 239 is being initialised
# Network 240 is being initialised
# Network 241 is being initialised
# Network 242 is being initialised
# Network 243 is being initialised
# Network 244 is being initialised
# Network 245 is being initialised
# Network 246 is being initialised
# Network 247 is being initialised
# Network 248 is being initialised
# Network 249 is being initialised
# Network 250 is being initialised
# Network 251 is being initialised
# Network 252 is being initialised
# Network 253 is being initialised
# Network 254 is being initialised
# Network 255 is being initialised
# Network 256 is being initialised
# Network 257 is being initialised
# Network 258 is being initialised
# Network 259 is being initialised
# Network 260 is being initialised
# Network 261 is being initialised
# Network 262 is being initialised
# Network 263 is being initialised
# Network 264 is being initialised
# Network 265 is being initialised
# Network 266 is being initialised
# Network 267 is being initialised
# Network 268 is being initialised
# Network 269 is being initialised
# Network 270 is being initialised
# Network 271 is being initialised
# Network 272 is being initialised
# Network 273 is being initialised
# Network 274 is being initialised
# Network 275 is being initialised
# Network 276 is being initialised
# Network 277 is being initialised
# Network 278 is being initialised
# Network 279 is being initialised
# Network 280 is being initialised
# Network 281 is being initialised
# Network 282 is being initialised
# Network 283 is being initialised
# Network 284 is being initialised
# Network 285 is being initialised
# Network 286 is being initialised
# Network 287 is being initialised
# Network 288 is being initialised
# Network 289 is being initialised
# Network 290 is being initialised
# Network 291 is being initialised
# Network 292 is being initialised
# Network 293 is being initialised
# Network 294 is being initialised
# Network 295 is being initialised
# Network 296 is being initialised
# Network 297 is being initialised
# Network 298 is being initialised
# Network 299 is being initialised
# Network 300 is being initialised
# Network 301 is being initialised
# Network 302 is being initialised
# Network 303 is being initialised
# Network 304 is being initialised
# Network 305 is being initialised
# Network 306 is being initialised
# Network 307 is being initialised
# Network 308 is being initialised
# Network 309 is being initialised
# Network 310 is being initialised
# Network 311 is being initialised
# Network 312 is being initialised
# Network 313 is being initialised
# Network 314 is being initialised
# Network 315 is being initialised
# Network 316 is being initialised
# Network 317 is being initialised
# Network 318 is being initialised
# Network 319 is being initialised
# Network 320 is being initialised
# Network 321 is being initialised
# Network 322 is being initialised
# Network 323 is being initialised
# Network 324 is being initialised
# Network 325 is being initialised
# Network 326 is being initialised
# Network 327 is being initialised
# Network 328 is being initialised
# Network 329 is being initialised
# Network 330 is being initialised
# Network 331 is being initialised
# Network 332 is being initialised
# Network 333 is being initialised
# Network 334 is being initialised
# Network 335 is being initialised
# Network 336 is being initialised
# Network 337 is being initialised
# Network 338 is being initialised
# Network 339 is being initialised
# Network 340 is being initialised
# Network 341 is being initialised
# Network 342 is being initialised
# Network 343 is being initialised
# Network 344 is being initialised
# Network 345 is being initialised
# Network 346 is being initialised
# Network 347 is being initialised

# %% [markdown]
# **Calculating Bayesian Lift and Bayesian Confidence**

# %%
#This function is used to retrive P(Xi|Par(Xi)) 
#from the CPD table of Xi
def getval(tabcpd):
  k = 0
  try:
    k = tabcpd.values[-1][-1][-1][-1]
  except:
    try:
      k = tabcpd.values[-1][-1][-1]
    except:
      try:
        k = tabcpd.values[-1][-1]
      except:
        k = tabcpd.values[-1]
  
  return k

# %%
bc = [0]*(len(networks)) #array to store bayesian confidence vals
bl = [0]*(len(networks)) #array to store bayesian lift values

for i in range(len(atob)):
  rule = atob[i]
  bay_net = networks[i]

  L = len(bay_net.nodes())
  all_cpds = bay_net.get_cpds()

  cpdprod = 1
  for cptab in all_cpds:
    cpdprod *= getval(cptab)

  bcval = pow(cpdprod/ant_supports[i], L)
  bc[i] = bcval
  bl[i] = bcval/con_supports[i]

print(bc)
print(bl)
# Out:
# [1.0, 0.21352988429499498, 0.19296714393566475, 0.005323128895677053, 0.004225671340494538, 0.0006734002771636011, 0.0004949693065966533, 0.9298469387755101, 0.9245562130177513, 0.9216, 0.9216, 0.9184027777777779, 0.9149338374291116, 0.9111570247933886, 0.6532806695693077, 0.9070294784580498, 0.8948137326515703, 0.87890625, 0.8751300728407907, 0.8573388203017831, 0.8573388203017831, 0.8573388203017831, 0.01887893223038244, 0.016068415308874626, 0.014608586440023327, 0.8444119795471148, 0.0001650333152749078, 0.8264462809917354, 0.8264462809917354, 0.8264462809917354, 0.024627648541428897, 0.0011413049267287034, 0.803804994054697, 0.001590226555839128, 0.7971938775510204, 0.7901234567901234, 0.7901234567901234, 0.7825443786982248, 0.7825443786982248, 0.7760770975056689, 0.7744, 2.754630588772672e-08, 0.7722681359044995, 0.7715485756026297, 0.765625, 0.765625, 0.7625471136679232, 0.47678197297539565, 0.7561436672967864, 0.7541551246537397, 0.0015314562740429882, 0.0014137056176027746, 0.7256515775034293, 0.4180678853513507, 7.8189292573155e-05, 0.7159763313609467, 0.709141274238227, 0.709141274238227, 0.7055999999999999, 0.00636394913716618, 0.701972242512783, 0.7001249479383591, 0.7001249479383591, 0.6944444444444445, 0.6944444444444445, 0.6944444444444445, 0.001709880033973458, 0.009971043539056174, 0.0013549344980716969, 0.683801775147929, 0.6806249999999999, 0.012594469683250604, 0.003224890559920873, 0.0025600221002267773, 0.3226348874146533, 1.3654096002836297e-07, 0.6655124653739611, 0.0015848183396136174, 0.6523668639053255, 0.011161097969177039, 0.0008123583035776235, 0.649587881488082, 0.005948208261280134, 0.6457270408163266, 0.6400000000000001, 0.5243865661439998, 0.6400000000000001, 0.006644672, 0.00043056471613202557, 0.00031647791991786976, 0.00012352973848402444, 0.6400000000000001, 3.520174868000844e-05, 0.6173469387755102, 0.6173469387755102, 0.36682730347362846, 0.6143170197224251, 0.6103515625000002, 0.6091612135633552,
# 1           9.298469e-01   1.215000e+00
# 2           9.245562e-01   1.208087e+00
# 3           9.216000e-01   6.690133e+00
# 4           9.216000e-01   1.204224e+00
# ..                   ...            ...
# 343         1.365410e-07   1.784135e-07
# 344         2.754631e-08   3.599384e-08
# 345         7.424753e-10   1.077964e-08
# 346         8.962873e-11   9.008837e-10
# 347         4.474954e-12   7.016727e-11
#
#                                                    A->  \
# 0                         [JUMBO BAG WOODLAND ANIMALS]
# 1                           [RED RETROSPOT PICNIC BAG]
# 2                      [SET OF 9 BLACK SKULL BALLOONS]
# 3                      [SET/6 RED SPOTTY PAPER PLATES]
# 4                         [PACK OF 6 SKULL PAPER CUPS]
# ..                                                 ...
# 343  [SET/6 RED SPOTTY PAPER PLATES, SET/6 RED SPOT...
# 344  [ALARM CLOCK BAKELIKE PINK, ALARM CLOCK BAKELI...
# 345                                          [POSTAGE]
# 346                                          [POSTAGE]
# 347                                          [POSTAGE]
#
#                                                      B
# 0                                            [POSTAGE]
# 1                                            [POSTAGE]
# 2                                            [POSTAGE]
# 3                        [SET/6 RED SPOTTY PAPER CUPS]
# 4                                            [POSTAGE]
# ..                                                 ...
# 343                                          [POSTAGE]
# 344                                          [POSTAGE]
# 345  [PLASTERS IN TIN WOODLAND ANIMALS, PLASTERS IN...
# 346  [SET/6 RED SPOTTY PAPER PLATES, SET/6 RED SPOT...
# 347  [ALARM CLOCK BAKELIKE PINK, ALARM CLOCK BAKELI...
#
# [348 rows x 4 columns]

# %%
answer2 = []
for i in range(len(atob)):
  answer2.append((bl[i],bc[i],atob[i][0],atob[i][1]))

answer2.sort(reverse = True)

ans_table2 = pd.DataFrame(answer2,columns=["Bayesian Lift","Bayesian Confidence","A  ->","B"])
ans_table2
# Out:
#      Bayesian Lift  Bayesian Confidence  \
# 0     1.295868e+01         8.264463e-01
# 1     1.200274e+01         8.573388e-01
# 2     1.157407e+01         7.971939e-01
# 3     1.140364e+01         6.400000e-01
# 4     7.241398e+00         7.019722e-01
# ..             ...                  ...
# 343   1.784135e-07         1.365410e-07
# 344   3.599384e-08         2.754631e-08
# 345   1.077964e-08         7.424753e-10
# 346   9.008837e-10         8.962873e-11
# 347   7.016727e-11         4.474954e-12
#
#                                                  A  ->  \
# 0                       [PACK OF 6 SKULL PAPER PLATES]
# 1                         [CHILDRENS CUTLERY SPACEBOY]
# 2                       [CHILDRENS CUTLERY DOLLY GIRL]
# 3                         [PACK OF 6 SKULL PAPER CUPS]
# 4                           [ALARM CLOCK BAKELIKE RED]
# ..                                                 ...
# 343  [SET/6 RED SPOTTY PAPER PLATES, SET/6 RED SPOT...
# 344  [ALARM CLOCK BAKELIKE PINK, ALARM CLOCK BAKELI...
# 345                                          [POSTAGE]
# 346                                          [POSTAGE]
# 347                                          [POSTAGE]
#
#                                                      B
# 0                         [PACK OF 6 SKULL PAPER CUPS]
# 1                       [CHILDRENS CUTLERY DOLLY GIRL]
# 2                         [CHILDRENS CUTLERY SPACEBOY]
# 3                       [PACK OF 6 SKULL PAPER PLATES]
# 4                         [ALARM CLOCK BAKELIKE GREEN]
# ..                                                 ...
# 343                                          [POSTAGE]
# 344                                          [POSTAGE]
# 345  [PLASTERS IN TIN WOODLAND ANIMALS, PLASTERS IN...
# 346  [SET/6 RED SPOTTY PAPER PLATES, SET/6 RED SPOT...
# 347  [ALARM CLOCK BAKELIKE PINK, ALARM CLOCK BAKELI...
#
# [348 rows x 4 columns]

# %% [markdown]
# **Observation**
#
# We see that the rules with high confidence, lift and support from our apriori algorithm also have high Bayesian confidence and Bayesian Lift.
#
# We also see that our top rule in Table 2 says that Buying paper plates (skull) implies byuying paper cups (skull). This is a very real life situation that comes up purely through our data analysis and association rule formation. This shows that our algorithms, Bayesian networks, confidence and lift work well!

# %% [markdown]
# **Thank you!**
